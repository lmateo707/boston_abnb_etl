# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
calendar_file = "calendar.csv"
calendar_df = pd.read_csv(calendar_file)
calendar_df.head()
# Out:
#    listing_id        date available price
# 0    12147973  2017-09-05         f   NaN
# 1    12147973  2017-09-04         f   NaN
# 2    12147973  2017-09-03         f   NaN
# 3    12147973  2017-09-02         f   NaN
# 4    12147973  2017-09-01         f   NaN

# %%
# convert to boolean
calendar_df["available"].replace(["t","f"], [True,False], inplace=True)

# %%
# remove dollar sign
calendar_df["price"] = calendar_df["price"].replace({'\$': '', ',': ''}, regex=True)
# convert the price column to numeric values 
calendar_df["price"] = pd.to_numeric(calendar_df["price"])
calendar_df.head()
# Out:
#    listing_id        date  available  price
# 0    12147973  2017-09-05      False    NaN
# 1    12147973  2017-09-04      False    NaN
# 2    12147973  2017-09-03      False    NaN
# 3    12147973  2017-09-02      False    NaN
# 4    12147973  2017-09-01      False    NaN

# %%
listings_file = "listings.csv"
listings_df = pd.read_csv(listings_file)
listings_df.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0  Roslindale is quiet, convenient and friendly. ...  ...                 NaN
# 1  The room is in Roslindale, a diverse and prima...  ...                 9.0
# 2  The LOCATION: Roslindale is a safe and diverse...  ...                10.0
# 3  Roslindale is a lovely little neighborhood loc...  ...                10.0
# 4  I love the proximity to downtown, the neighbor...  ...                10.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                t
# 2                f     NaN                NaN                f
# 3                f     NaN                NaN                f
# 4                f     NaN                NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
# 2            moderate                             t
# 3            moderate                             f
# 4            flexible                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
# 2                                f                              1
# 3                                f                              1
# 4                                f                              1
#
#    reviews_per_month
# 0                NaN
# 1               1.30
# 2               0.47
# 3               1.00
# 4               2.25
#
# [5 rows x 95 columns]

# %%
reviews_file = "reviews.csv"
reviews_df = pd.read_csv(reviews_file)
reviews_df.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0     1178162  4724140  2013-05-21      4298113       Olivier
# 1     1178162  4869189  2013-05-29      6452964     Charlotte
# 2     1178162  5003196  2013-06-06      6449554     Sebastian
# 3     1178162  5150351  2013-06-15      2215611        Marine
# 4     1178162  5171140  2013-06-16      6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %%
#merge listings and calendar
listings_calendar_df = listings_df.merge(calendar_df, left_on='id', right_on='listing_id')

#sanity check
listings_calendar_df
# Out:
#                id                            listing_url       scrape_id  \
# 0        12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1        12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 2        12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 3        12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 4        12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# ...           ...                                    ...             ...
# 1308885  14504422  https://www.airbnb.com/rooms/14504422  20160906204935
# 1308886  14504422  https://www.airbnb.com/rooms/14504422  20160906204935
# 1308887  14504422  https://www.airbnb.com/rooms/14504422  20160906204935
# 1308888  14504422  https://www.airbnb.com/rooms/14504422  20160906204935
# 1308889  14504422  https://www.airbnb.com/rooms/14504422  20160906204935
#
#         last_scraped                                name  \
# 0         2016-09-07          Sunny Bungalow in the City
# 1         2016-09-07          Sunny Bungalow in the City
# 2         2016-09-07          Sunny Bungalow in the City
# 3         2016-09-07          Sunny Bungalow in the City
# 4         2016-09-07          Sunny Bungalow in the City
# ...              ...                                 ...
# 1308885   2016-09-07  (K1) Private Room near Harvard/MIT
# 1308886   2016-09-07  (K1) Private Room near Harvard/MIT
# 1308887   2016-09-07  (K1) Private Room near Harvard/MIT
# 1308888   2016-09-07  (K1) Private Room near Harvard/MIT
# 1308889   2016-09-07  (K1) Private Room near Harvard/MIT
#
#                                                    summary  \
# 0        Cozy, sunny, family home.  Master bedroom high...
# 1        Cozy, sunny, family home.  Master bedroom high...
# 2        Cozy, sunny, family home.  Master bedroom high...
# 3        Cozy, sunny, family home.  Master bedroom high...
# 4        Cozy, sunny, family home.  Master bedroom high...
# ...                                                    ...
# 1308885  My place is close to My home is a warm and fri...
# 1308886  My place is close to My home is a warm and fri...
# 1308887  My place is close to My home is a warm and fri...
# 1308888  My place is close to My home is a warm and fri...
# 1308889  My place is close to My home is a warm and fri...
#
#                                                      space  \
# 0        The house has an open and cozy feel at the sam...
# 1        The house has an open and cozy feel at the sam...
# 2        The house has an open and cozy feel at the sam...
# 3        The house has an open and cozy feel at the sam...
# 4        The house has an open and cozy feel at the sam...
# ...                                                    ...
# 1308885  To ensure a smooth check in: 1. You MUST have ...
# 1308886  To ensure a smooth check in: 1. You MUST have ...
# 1308887  To ensure a smooth check in: 1. You MUST have ...
# 1308888  To ensure a smooth check in: 1. You MUST have ...
# 1308889  To ensure a smooth check in: 1. You MUST have ...
#
#                                                description  \
# 0        Cozy, sunny, family home.  Master bedroom high...
# 1        Cozy, sunny, family home.  Master bedroom high...
# 2        Cozy, sunny, family home.  Master bedroom high...
# 3        Cozy, sunny, family home.  Master bedroom high...
# 4        Cozy, sunny, family home.  Master bedroom high...
# ...                                                    ...
# 1308885  My place is close to My home is a warm and fri...
# 1308886  My place is close to My home is a warm and fri...
# 1308887  My place is close to My home is a warm and fri...
# 1308888  My place is close to My home is a warm and fri...
# 1308889  My place is close to My home is a warm and fri...
#
#         experiences_offered  \
# 0                      none
# 1                      none
# 2                      none
# 3                      none
# 4                      none
# ...                     ...
# 1308885                none
# 1308886                none
# 1308887                none
# 1308888                none
# 1308889                none
#
#                                      neighborhood_overview  ...  \
# 0        Roslindale is quiet, convenient and friendly. ...  ...
# 1        Roslindale is quiet, convenient and friendly. ...  ...
# 2        Roslindale is quiet, convenient and friendly. ...  ...
# 3        Roslindale is quiet, convenient and friendly. ...  ...
# 4        Roslindale is quiet, convenient and friendly. ...  ...
# ...                                                    ...  ...
# 1308885                                                NaN  ...
# 1308886                                                NaN  ...
# 1308887                                                NaN  ...
# 1308888                                                NaN  ...
# 1308889                                                NaN  ...
#
#         instant_bookable cancellation_policy require_guest_profile_picture  \
# 0                      f            moderate                             f
# 1                      f            moderate                             f
# 2                      f            moderate                             f
# 3                      f            moderate                             f
# 4                      f            moderate                             f
# ...                  ...                 ...                           ...
# 1308885                t            flexible                             f
# 1308886                t            flexible                             f
# 1308887                t            flexible                             f
# 1308888                t            flexible                             f
# 1308889                t            flexible                             f
#
#         require_guest_phone_verification calculated_host_listings_count  \
# 0                                      f                              1
# 1                                      f                              1
# 2                                      f                              1
# 3                                      f                              1
# 4                                      f                              1
# ...                                  ...                            ...
# 1308885                                f                              3
# 1308886                                f                              3
# 1308887                                f                              3
# 1308888                                f                              3
# 1308889                                f                              3
#
#         reviews_per_month listing_id        date available  price_y
# 0                     NaN   12147973  2017-09-05     False      NaN
# 1                     NaN   12147973  2017-09-04     False      NaN
# 2                     NaN   12147973  2017-09-03     False      NaN
# 3                     NaN   12147973  2017-09-02     False      NaN
# 4                     NaN   12147973  2017-09-01     False      NaN
# ...                   ...        ...         ...       ...      ...
# 1308885               NaN   14504422  2016-09-10     False      NaN
# 1308886               NaN   14504422  2016-09-09     False      NaN
# 1308887               NaN   14504422  2016-09-08     False      NaN
# 1308888               NaN   14504422  2016-09-07     False      NaN
# 1308889               NaN   14504422  2016-09-06     False      NaN
#
# [1308890 rows x 99 columns]

# %%
#transform data goes here

# %%
#choose only the necessary columns
cleaned_df = listings_calendar_df[["id", "name", "price_y", "number_of_reviews", "review_scores_rating", "date", "available"]]

#sanity check
cleaned_df.head()
# Out:
#          id                        name  price_y  number_of_reviews  \
# 0  12147973  Sunny Bungalow in the City      NaN                  0
# 1  12147973  Sunny Bungalow in the City      NaN                  0
# 2  12147973  Sunny Bungalow in the City      NaN                  0
# 3  12147973  Sunny Bungalow in the City      NaN                  0
# 4  12147973  Sunny Bungalow in the City      NaN                  0
#
#    review_scores_rating        date  available
# 0                   NaN  2017-09-05      False
# 1                   NaN  2017-09-04      False
# 2                   NaN  2017-09-03      False
# 3                   NaN  2017-09-02      False
# 4                   NaN  2017-09-01      False

# %%
#drop na's
dropped_listings_df = cleaned_df.dropna(how='any', axis=0)

#sanity check
dropped_listings_df
# Out:
#                id                                   name  price_y  \
# 365       3075044      Charming room in pet friendly apt     65.0
# 366       3075044      Charming room in pet friendly apt     65.0
# 367       3075044      Charming room in pet friendly apt     65.0
# 368       3075044      Charming room in pet friendly apt     75.0
# 369       3075044      Charming room in pet friendly apt     75.0
# ...           ...                                    ...      ...
# 1308518  14603878  Great Location; Train and Restaurants     59.0
# 1308519  14603878  Great Location; Train and Restaurants     59.0
# 1308520  14603878  Great Location; Train and Restaurants     59.0
# 1308521  14603878  Great Location; Train and Restaurants     59.0
# 1308522  14603878  Great Location; Train and Restaurants     59.0
#
#          number_of_reviews  review_scores_rating        date  available
# 365                     36                  94.0  2017-08-22       True
# 366                     36                  94.0  2017-08-21       True
# 367                     36                  94.0  2017-08-20       True
# 368                     36                  94.0  2017-08-19       True
# 369                     36                  94.0  2017-08-18       True
# ...                    ...                   ...         ...        ...
# 1308518                  2                  90.0  2016-09-12       True
# 1308519                  2                  90.0  2016-09-11       True
# 1308520                  2                  90.0  2016-09-10       True
# 1308521                  2                  90.0  2016-09-09       True
# 1308522                  2                  90.0  2016-09-08       True
#
# [518677 rows x 7 columns]

# %%
#show only those with rating greater than 50

#index of rows with rating greater than 50
indexNames = dropped_listings_df[dropped_listings_df['review_scores_rating'] < 90.0].index


#drop the valuues with rating greater than 300
dropped_listings_df.drop(indexNames , inplace=True)

#sanity check that its over 100 daata entries
print(f'Data Entries: {len(dropped_listings_df)}')

#sanity check
dropped_listings_df.head()
# Out:
# Data Entries: 365313
# /Users/noetorres/opt/miniconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#           id                               name  price_y  number_of_reviews  \
# 365  3075044  Charming room in pet friendly apt     65.0                 36
# 366  3075044  Charming room in pet friendly apt     65.0                 36
# 367  3075044  Charming room in pet friendly apt     65.0                 36
# 368  3075044  Charming room in pet friendly apt     75.0                 36
# 369  3075044  Charming room in pet friendly apt     75.0                 36
#
#      review_scores_rating        date  available
# 365                  94.0  2017-08-22       True
# 366                  94.0  2017-08-21       True
# 367                  94.0  2017-08-20       True
# 368                  94.0  2017-08-19       True
# 369                  94.0  2017-08-18       True

# %%
#create database connection
connection = "postgres:postgres@localhost:5432/airbnb_db"
engine = create_engine(f'postgresql://{connection}')

# %%
#table names
engine.table_names()

# %%
#load df into database
calendar.to_sql(name='premise', con=engine, if_exists='append', index=True)

# %%
listings.to_sql(name='county', con=engine, if_exists='append', index=True)

# %%
reviews.to_sql(name='county', con=engine, if_exists='append', index=True)

# %%
#query results to confirm data has been added
pd.read_sql_query('select * from calendar', con=engine).head()

# %%
pd.read_sql_query('select * from listings', con=engine).head()

# %%
pd.read_sql_query('select * from reviews', con=engine).head()
